# %% [markdown]
# ## Q2
# by 王邦碩 Brian

# %%
import numpy as np
import matplotlib.pyplot as plt

U = np.random.uniform(0, 1, 100000)

x_pos = (-1 + np.sqrt(1 - 2 * (2 - 4 * U))) / 2
x_neg = (-1 - np.sqrt(1 - 2 * (2 - 4 * U))) / 2


x_pos_filtered = x_pos[(x_pos >= -1) & (x_pos <= 1)]
x_neg_filtered = x_neg[(x_neg >= -1) & (x_neg <= 1)]

#x_combined = np.concatenate([x_pos_filtered, x_neg_filtered])
x_combined = np.concatenate([x_pos, x_neg])

plt.hist(x_combined, bins=50, density=True, label=r'density of x generated by $x^{-1}(U)$')


x = np.linspace(-1, 1, 500)
f_x = (1 + 2 * x) / 2
plt.plot(x, f_x, label=r'$f(x) = \frac{1 + 2x}{2}$', color='red')

plt.xlabel(r'$x$')
plt.ylabel('Probability Density / xunction Value')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\88690\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in sqrt
#
# C:\Users\88690\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in sqrt
#   import sys
